# %%
x<-TRUE

# %%
y<-TRUE

# %%
x&y
# Out:
# [1] TRUE

# %%
TRUE&TRUE
# Out:
# [1] TRUE

# %%
TRUE&FALSE
# Out:
# [1] FALSE

# %%
FALSE&FALSE
# Out:
# [1] FALSE

# %%
TRUE|TRUE
# Out:
# [1] TRUE

# %%
TRUE|FALSE
# Out:
# [1] TRUE

# %%
FALSE|FALSE
# Out:
# [1] FALSE

# %%
!TRUE
# Out:
# [1] FALSE

# %%
!FALSE
# Out:
# [1] TRUE

# %%
10&10
# Out:
# [1] TRUE

# %%
10&0
# Out:
# [1] FALSE

# %%
!10
# Out:
# [1] FALSE

# %%
!0
# Out:
# [1] TRUE

# %%
!-3
# Out:
# [1] FALSE

# %%
!"Hello"
# Out:
# Error in !"Hello": invalid argument type
# Traceback:
